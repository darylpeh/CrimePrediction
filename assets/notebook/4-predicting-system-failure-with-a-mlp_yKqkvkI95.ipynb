# %% [markdown]
# # Introduction: Predicting failures with a MLP

# %% [markdown]
# Notebook by Jürgen Brauer, [www.juergenbrauer.org](http://www.juergenbrauer.org)
#
# In this notebook we will show that we can learn a MLP for predicting whether a System will fail in a future time window or not. The prediction failure classification rate is about 97% for the following settings.
#
# The input for the MLP is a time window of some specified length of the System  sensor data (52 sensors, called "sensor_00" till "sensor_51").
#
# The output of the MLP is a single output neuron:
# - 0 means: there will be no failure (machine status "NORMAL")
# - 1 means: there will be a machine failure (machine status "BROKEN"/"RECOVERING").
#
# The following settings are used:

# %%
nr_examples_to_prepare = 2000
window_width_input_minutes = 60
window_width_output_minutes = 60*24

# %% [markdown]
# The MLP will be trained e.g. on 2000/2=1000 training samples, where the input window covers 60 minutes (1 hour of sensor data).
#
# The MLP input vector x length will be accordingly 60 minutes x 52 sensor samples/minute = a 3120-dimensional input vector.
#
# The MLP output vector y length is 1 (just one output neuron).
# For checking whether there was a machine failure after the input window (so for generating the teacher vectors y), we check in some time window of length 60 x 24 (i.e. 1 day = 60 minutes * 24 hours), whether the machine went into state "BROKEN" or "RECOVERING".
#
# 1000 randomly extracted samples (x,y) will be used for training.
#
# 1000 randomly extracted samples (x,y) will be used for testing.
#
# For generating one of these 2000 training samples we
# - randomly choose a sample minute
# - compute the input vector x from the input window starting at this minute
# - compute the output vector y by checking whether in the following time window the machine failed
# - combine both the input and output vector into one training sample (x,y)

# %% [markdown]
# # Sketch of the approach

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Read in the sensor and machine status data

# %%
import pandas
print("Your Pandas version is ", pandas.__version__)
#fname = "/kaggle/input/machine-sensor-data/sensor.csv"
#df = pandas.read_csv( fname )

df = pandas.read_csv('/project_data/data_asset/4_sensor.csv')
# Out:
# Your Pandas version is  1.0.1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# The first column has no name. Give it a name!
df.rename(columns={ df.columns[0]: "Samplenr" }, inplace = True)

# %%
df[:5]
# Out:
#    Samplenr            timestamp  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760
# 1         1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760
# 2         2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570
# 3         3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568
# 4         4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568
#
#    sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  sensor_44  \
# 0   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 1   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 2   638.8889   73.54598   13.32465   16.03733  ...   41.66666  39.351852
# 3   628.1250   76.98898   13.31742   16.24711  ...   40.88541  39.062500
# 4   636.4583   76.58897   13.35359   16.21094  ...   41.40625  38.773150
#
#    sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  \
# 0   65.68287   50.92593  38.194440   157.9861   67.70834   243.0556
# 1   65.68287   50.92593  38.194440   157.9861   67.70834   243.0556
# 2   65.39352   51.21528  38.194443   155.9606   67.12963   241.3194
# 3   64.81481   51.21528  38.194440   155.9606   66.84028   240.4514
# 4   65.10416   51.79398  38.773150   158.2755   66.55093   242.1875
#
#    sensor_51  machine_status
# 0   201.3889          NORMAL
# 1   201.3889          NORMAL
# 2   203.7037          NORMAL
# 3   203.1250          NORMAL
# 4   201.3889          NORMAL
#
# [5 rows x 55 columns]

# %% [markdown]
# # Show some of the rows from the .csv file

# %%
df.head(7)
# Out:
#    Samplenr            timestamp  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760
# 1         1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760
# 2         2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570
# 3         3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568
# 4         4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568
# 5         5  2018-04-01 00:05:00   2.453588   47.09201    53.1684  46.397568
# 6         6  2018-04-01 00:06:00   2.455556   47.04861    53.1684  46.397568
#
#    sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  sensor_44  \
# 0   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 1   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 2   638.8889   73.54598   13.32465   16.03733  ...   41.66666  39.351852
# 3   628.1250   76.98898   13.31742   16.24711  ...   40.88541  39.062500
# 4   636.4583   76.58897   13.35359   16.21094  ...   41.40625  38.773150
# 5   637.6157   78.18568   13.41146   16.16753  ...   42.70833  38.773150
# 6   633.3333   75.81614   13.43316   16.13136  ...   43.22916  38.194440
#
#    sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  \
# 0   65.68287   50.92593  38.194440   157.9861   67.70834   243.0556
# 1   65.68287   50.92593  38.194440   157.9861   67.70834   243.0556
# 2   65.39352   51.21528  38.194443   155.9606   67.12963   241.3194
# 3   64.81481   51.21528  38.194440   155.9606   66.84028   240.4514
# 4   65.10416   51.79398  38.773150   158.2755   66.55093   242.1875
# 5   63.65741   51.79398  38.773150   164.6412   66.55093   241.6088
# 6   61.92130   51.79398  39.062500   171.8750   67.70834   240.1620
#
#    sensor_51  machine_status
# 0   201.3889          NORMAL
# 1   201.3889          NORMAL
# 2   203.7037          NORMAL
# 3   203.1250          NORMAL
# 4   201.3889          NORMAL
# 5   201.6782          NORMAL
# 6   200.2315          NORMAL
#
# [7 rows x 55 columns]

# %%
df.tail(3)
# Out:
#         Samplenr            timestamp  sensor_00  sensor_01  sensor_02  \
# 220317    220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318    220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319    220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 220317  43.142361  625.925903   67.29445   15.08970   16.70284  ...
# 220318  43.142361  635.648100   65.09175   15.11863   16.56539  ...
# 220319  43.142361  639.814800   65.45634   15.11863   16.65220  ...
#
#         sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# 220317   39.06250   65.39352   48.90046   48.03241  40.798610   217.3032
# 220318   40.62500   64.23611   47.74306   48.32176  40.509258   222.5116
# 220319   41.40625   62.78935   46.29630   48.90046  40.219910   227.4306
#
#         sensor_49  sensor_50  sensor_51  machine_status
# 220317   155.3819        NaN   232.0602          NORMAL
# 220318   153.9352        NaN   234.0856          NORMAL
# 220319   150.4630        NaN   234.0856          NORMAL
#
# [3 rows x 55 columns]

# %%
df.dtypes
# Out:
# Samplenr            int64
# timestamp          object
# sensor_00         float64
# sensor_01         float64
# sensor_02         float64
# sensor_03         float64
# sensor_04         float64
# sensor_05         float64
# sensor_06         float64
# sensor_07         float64
# sensor_08         float64
# sensor_09         float64
# sensor_10         float64
# sensor_11         float64
# sensor_12         float64
# sensor_13         float64
# sensor_14         float64
# sensor_15         float64
# sensor_16         float64
# sensor_17         float64
# sensor_18         float64
# sensor_19         float64
# sensor_20         float64
# sensor_21         float64
# sensor_22         float64
# sensor_23         float64
# sensor_24         float64
# sensor_25         float64
# sensor_26         float64
# sensor_27         float64
# sensor_28         float64
# sensor_29         float64
# sensor_30         float64
# sensor_31         float64
# sensor_32         float64
# sensor_33         float64
# sensor_34         float64
# sensor_35         float64
# sensor_36         float64
# sensor_37         float64
# sensor_38         float64
# sensor_39         float64
# sensor_40         float64
# sensor_41         float64
# sensor_42         float64
# sensor_43         float64
# sensor_44         float64
# sensor_45         float64
# sensor_46         float64
# sensor_47         float64
# sensor_48         float64
# sensor_49         float64
# sensor_50         float64
# sensor_51         float64
# machine_status     object
# dtype: object

# %%
df.describe()
# Out:
#             Samplenr      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  210112.000000  219951.000000  220301.000000
# mean   110159.500000       2.372221      47.591611      50.867392
# std     63601.049991       0.412227       3.296666       3.666820
# min         0.000000       0.000000       0.000000      33.159720
# 25%     55079.750000       2.438831      46.310760      50.390620
# 50%    110159.500000       2.456539      48.133678      51.649300
# 75%    165239.250000       2.499826      49.479160      52.777770
# max    220319.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220301.000000  220301.000000  220301.000000  215522.000000
# mean       43.752481     590.673936      73.396414      13.501537
# std         2.418887     144.023912      17.298247       2.163736
# min        31.640620       2.798032       0.000000       0.014468
# 25%        42.838539     626.620400      69.976260      13.346350
# 50%        44.227428     632.638916      75.576790      13.642940
# 75%        45.312500     637.615723      80.912150      14.539930
# max        48.220490     800.000000      99.999880      22.251160
#
#            sensor_07      sensor_08  ...      sensor_42      sensor_43  \
# count  214869.000000  215213.000000  ...  220293.000000  220293.000000
# mean       15.843152      15.200721  ...      35.453455      43.879591
# std         2.201155       2.037390  ...      10.259521      11.044404
# min         0.000000       0.028935  ...      22.135416      24.479166
# 25%        15.907120      15.183740  ...      32.812500      39.583330
# 50%        16.167530      15.494790  ...      35.156250      42.968750
# 75%        16.427950      15.697340  ...      36.979164      46.614580
# max        23.596640      24.348960  ...     374.218800     408.593700
#
#            sensor_44      sensor_45      sensor_46      sensor_47  \
# count  220293.000000  220293.000000  220293.000000  220293.000000
# mean       42.656877      43.094984      48.018585      44.340903
# std        11.576355      12.837520      15.641284      10.442437
# min        25.752316      26.331018      26.331018      27.199070
# 25%        36.747684      36.747684      40.509258      39.062500
# 50%        40.509260      40.219910      44.849540      42.534720
# 75%        45.138890      44.849540      51.215280      46.585650
# max      1000.000000     320.312500     370.370400     303.530100
#
#            sensor_48      sensor_49      sensor_50      sensor_51
# count  220293.000000  220293.000000  143303.000000  204937.000000
# mean      150.889044      57.119968     183.049260     202.699667
# std        82.244957      19.143598      65.258650     109.588607
# min        26.331018      26.620370      27.488426      27.777779
# 25%        83.912030      47.743060     167.534700     179.108800
# 50%       138.020800      52.662040     193.865700     197.338000
# 75%       208.333300      60.763890     219.907400     216.724500
# max       561.632000     464.409700    1000.000000    1000.000000
#
# [8 rows x 53 columns]

# %% [markdown]
# # Which different machine states are there and how often?

# %%
possible_machine_states = list(df.machine_status.unique())

# %%
possible_machine_states
# Out:
# ['NORMAL', 'BROKEN', 'RECOVERING']

# %%
# Get all rows where machine status was "NORMAL"
df_status_NORMAL = df[ df["machine_status"] == "NORMAL" ]

# %%
type(df_status_NORMAL)
# Out:
# pandas.core.frame.DataFrame

# %%
df_status_NORMAL.shape
# Out:
# (205836, 55)

# %%
nr_rows_machine_status_NORMAL = df_status_NORMAL.shape[0]

# %%
nr_rows_machine_status_NORMAL
# Out:
# 205836

# %%
nr_rows_total = df.shape[0]

# %%
nr_rows_total
# Out:
# 220320

# %%
percent_machine_status_NORMAL = \
    (nr_rows_machine_status_NORMAL / nr_rows_total) * 100.0

# %%
percent_machine_status_NORMAL
# Out:
# 93.42592592592592

# %%
df_status_BROKEN = df[ df["machine_status"] == "BROKEN" ]

# %%
df_status_BROKEN
# Out:
#         Samplenr            timestamp  sensor_00  sensor_01  sensor_02  \
# 17155      17155  2018-04-12 21:55:00   0.000000  53.342010  52.821180
# 24510      24510  2018-04-18 00:30:00   1.093982  42.534720  47.699650
# 69318      69318  2018-05-19 03:18:00   2.258796  47.265630  52.734370
# 77790      77790  2018-05-25 00:30:00   2.321759  47.482640  51.475693
# 128040    128040  2018-06-28 22:00:00   0.364005  40.190970  45.225690
# 141131    141131  2018-07-08 00:11:00   0.001968  45.138890  52.907990
# 166440    166440  2018-07-25 14:00:00   2.318808  45.833332  52.994790
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 17155   43.402775  202.526031   49.79289   3.219039  16.890910  ...
# 24510   41.449650  206.038757   60.30106  12.304690  15.154800  ...
# 69318   43.446178  200.115738   66.14643  13.592300  15.914350  ...
# 77790   42.795135  612.152800   67.30158  14.062500  16.608800  ...
# 128040  40.190971  201.368622    0.00000  11.335360  15.270540  ...
# 141131  45.355900  500.000000    1.40131   0.028935   0.036169  ...
# 166440  43.880210  420.503448   72.52040  14.185470  16.247110  ...
#
#         sensor_43  sensor_44  sensor_45   sensor_46   sensor_47   sensor_48  \
# 17155    50.78125   50.92593  51.215280   50.636570   46.006940  409.143500
# 24510    42.70833   34.72222  31.539350   34.432870   33.275460   59.895830
# 69318    39.06250   35.01157  37.905090   39.062500   45.428240  144.675900
# 77790   202.34370   65.68287  57.870370  127.893500  153.935200  155.381900
# 128040   32.29166   28.06713  28.067129   29.513889   29.224537   29.224537
# 141131   36.19791   37.32639  35.300930   38.194440   43.402780   99.537030
# 166440   51.30208   52.10200  52.662040   67.129630   43.981480  230.324100
#
#          sensor_49   sensor_50  sensor_51  machine_status
# 17155   121.527800  401.909700   324.6528          BROKEN
# 24510    44.560180  177.662000   183.7384          BROKEN
# 69318    49.768520  246.238400   257.5231          BROKEN
# 77790    65.682870  220.196800   267.3611          BROKEN
# 128040   29.513889   32.407406        NaN          BROKEN
# 141131   44.849540  192.129600   174.7685          BROKEN
# 166440   69.733800         NaN   205.7292          BROKEN
#
# [7 rows x 55 columns]

# %%
nr_rows_machine_status_BROKEN = df_status_BROKEN.shape[0]

# %%
print("So {0} times, the machine was broken".format(nr_rows_machine_status_BROKEN))
# Out:
# So 7 times, the pump was broken

# %%
df_status_RECOVERING = df[ df["machine_status"] == "RECOVERING" ]
nr_rows_machine_status_RECOVERING = df_status_RECOVERING.shape[0]

# %%
percent_machine_status_RECOVERING = \
    (nr_rows_machine_status_RECOVERING / nr_rows_total) * 100.0

# %%
percent_machine_status_RECOVERING
# Out:
# 6.570896877269426

# %%
import matplotlib.pyplot as plt

xpos = [1,2,3]
data = [nr_rows_machine_status_NORMAL,
        nr_rows_machine_status_BROKEN,
        nr_rows_machine_status_RECOVERING]

fig, ax = plt.subplots()
ax.bar(xpos,data)
ax.set_xticks(xpos)
ax.set_xticklabels(possible_machine_states)
ax.set_title("How often was the machine in each machine state?")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c93019c86ee> in <module>
#       2
#       3 xpos = [1,2,3]
# ----> 4 data = [nr_rows_machine_status_NORMAL,
#       5         nr_rows_machine_status_BROKEN,
#       6         nr_rows_machine_status_RECOVERING]
#
# NameError: name 'nr_rows_machine_status_NORMAL' is not defined

# %% [markdown]
# # How long did the 7 RECOVERING phases need?

# %%
df_status_BROKEN
# Out:
#         Samplenr            timestamp  sensor_00  sensor_01  sensor_02  \
# 17155      17155  2018-04-12 21:55:00   0.000000  53.342010  52.821180
# 24510      24510  2018-04-18 00:30:00   1.093982  42.534720  47.699650
# 69318      69318  2018-05-19 03:18:00   2.258796  47.265630  52.734370
# 77790      77790  2018-05-25 00:30:00   2.321759  47.482640  51.475693
# 128040    128040  2018-06-28 22:00:00   0.364005  40.190970  45.225690
# 141131    141131  2018-07-08 00:11:00   0.001968  45.138890  52.907990
# 166440    166440  2018-07-25 14:00:00   2.318808  45.833332  52.994790
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 17155   43.402775  202.526031   49.79289   3.219039  16.890910  ...
# 24510   41.449650  206.038757   60.30106  12.304690  15.154800  ...
# 69318   43.446178  200.115738   66.14643  13.592300  15.914350  ...
# 77790   42.795135  612.152800   67.30158  14.062500  16.608800  ...
# 128040  40.190971  201.368622    0.00000  11.335360  15.270540  ...
# 141131  45.355900  500.000000    1.40131   0.028935   0.036169  ...
# 166440  43.880210  420.503448   72.52040  14.185470  16.247110  ...
#
#         sensor_43  sensor_44  sensor_45   sensor_46   sensor_47   sensor_48  \
# 17155    50.78125   50.92593  51.215280   50.636570   46.006940  409.143500
# 24510    42.70833   34.72222  31.539350   34.432870   33.275460   59.895830
# 69318    39.06250   35.01157  37.905090   39.062500   45.428240  144.675900
# 77790   202.34370   65.68287  57.870370  127.893500  153.935200  155.381900
# 128040   32.29166   28.06713  28.067129   29.513889   29.224537   29.224537
# 141131   36.19791   37.32639  35.300930   38.194440   43.402780   99.537030
# 166440   51.30208   52.10200  52.662040   67.129630   43.981480  230.324100
#
#          sensor_49   sensor_50  sensor_51  machine_status
# 17155   121.527800  401.909700   324.6528          BROKEN
# 24510    44.560180  177.662000   183.7384          BROKEN
# 69318    49.768520  246.238400   257.5231          BROKEN
# 77790    65.682870  220.196800   267.3611          BROKEN
# 128040   29.513889   32.407406        NaN          BROKEN
# 141131   44.849540  192.129600   174.7685          BROKEN
# 166440   69.733800         NaN   205.7292          BROKEN
#
# [7 rows x 55 columns]

# %%
row_numbers_machine_BROKEN = list(df_status_BROKEN["Samplenr"].values)

# %%
row_numbers_machine_BROKEN
# Out:
# [17155, 24510, 69318, 77790, 128040, 141131, 166440]

# %%
recovering_times_hours = []

for i in row_numbers_machine_BROKEN:
    print("\nMachine in status BROKEN in row: {0}".format(i) )
    
    go_further = True
    j = i
    while go_further:
        j += 1
        machine_status_in_row_j = df.iloc[j]["machine_status"]        
        if machine_status_in_row_j != "RECOVERING":
            go_further = False
            
    print("Machine went back to status {0} in row: {1}"
          .format(machine_status_in_row_j, j-i)
          )
    recovering_hours = (j-i)/60
    recovering_days  = recovering_hours / 24
    print("Machine was in RECOVERING state for {0:.1f} hours / {1:.1f} days"
          .format( recovering_hours, recovering_days )
         )
    
    recovering_times_hours.append(recovering_hours)
# Out:
# Machine in status BROKEN in row: 17155
# Machine went back to status NORMAL in row: 945
# Machine was in RECOVERING state for 15.8 hours / 0.7 days
#
# Machine in status BROKEN in row: 24510
# Machine went back to status NORMAL in row: 3111
# Machine was in RECOVERING state for 51.9 hours / 2.2 days
#
# Machine in status BROKEN in row: 69318
# Machine went back to status NORMAL in row: 1313
# Machine was in RECOVERING state for 21.9 hours / 0.9 days
#
# Machine in status BROKEN in row: 77790
# Machine went back to status NORMAL in row: 606
# Machine was in RECOVERING state for 10.1 hours / 0.4 days
#
# Machine in status BROKEN in row: 128040
# Machine went back to status NORMAL in row: 8391
# Machine was in RECOVERING state for 139.8 hours / 5.8 days
#
# Machine in status BROKEN in row: 141131
# Machine went back to status NORMAL in row: 42
# Machine was in RECOVERING state for 0.7 hours / 0.0 days
#
# Machine in status BROKEN in row: 166440
# Machine went back to status NORMAL in row: 76
# Machine was in RECOVERING state for 1.3 hours / 0.1 days

# %%
recovering_times_hours
# Out:
# [15.75, 51.85, 21.883333333333333, 10.1, 139.85, 0.7, 1.2666666666666666]

# %%
import matplotlib.pyplot as plt
import numpy as np

xpos = np.arange( len(recovering_times_hours) )

fig, ax = plt.subplots()
ax.bar(xpos,recovering_times_hours)
ax.set_xticks(xpos)
ax.set_xticklabels(xpos)
ax.set_title("Duration of RECOVERING phase [in hours] for each of the 7 machine failures")
plt.show()

# %%
min(recovering_times_hours)
# Out:
# 0.7

# %%
max(recovering_times_hours)
# Out:
# 139.85

# %% [markdown]
# # Visualize some of the sensor data

# %%
df["sensor_17"]
# Out:
# 0         466.3284
# 1         466.3284
# 2         459.6364
# 3         460.8858
# 4         468.2206
#             ...
# 220315    458.3615
# 220316    468.4388
# 220317    468.6293
# 220318    459.7941
# 220319    456.5726
# Name: sensor_17, Length: 220320, dtype: float64

# %%
type( df["sensor_17"] )
# Out:
# pandas.core.series.Series

# %%
sensor_values = list( df["sensor_17"] )

# %%
type(sensor_values)
# Out:
# list

# %%
len(sensor_values)
# Out:
# 220320

# %%
sensor_values[:10]
# Out:
# [466.3284,
#  466.3284,
#  459.6364,
#  460.8858,
#  468.2206,
#  461.9289,
#  467.5146,
#  463.8936,
#  461.546,
#  468.8477]

# %%
import matplotlib.pyplot as plt

some_few_values = sensor_values[:100]
min_val = min(some_few_values)
max_val = max(some_few_values)

plt.plot( some_few_values, color="green", linestyle="-",
          marker=".", linewidth=0.5 )
plt.hlines(min_val, 0,100, color="blue")
plt.hlines(max_val, 0,100, color="red")
plt.xlabel("Minute", fontsize=10)
plt.ylabel("Sensor value", fontsize=10)
plt.title("The first 100 sensor values of Sensor 17", fontsize=14)
plt.grid()
#plt.savefig("sensor_17.png")
plt.show()

# %% [markdown]
# # Fill data gaps (NaN values)

# %% [markdown]
# How many missing values are there in total?

# %%
df.isna().sum().sum()
# Out:
# 344574

# %%
df.isna().sum()
# Out:
# Samplenr               0
# timestamp              0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# sensor_35             16
# sensor_36             16
# sensor_37             16
# sensor_38             27
# sensor_39             27
# sensor_40             27
# sensor_41             27
# sensor_42             27
# sensor_43             27
# sensor_44             27
# sensor_45             27
# sensor_46             27
# sensor_47             27
# sensor_48             27
# sensor_49             27
# sensor_50          77017
# sensor_51          15383
# machine_status         0
# dtype: int64

# %%
only_numerical_cols = df.iloc[:,2:54]

# %%
only_numerical_cols
# Out:
#         sensor_00  sensor_01  sensor_02  sensor_03   sensor_04  sensor_05  \
# 0        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 1        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 2        2.444734   47.35243  53.211800  46.397570  638.888900   73.54598
# 3        2.460474   47.09201  53.168400  46.397568  628.125000   76.98898
# 4        2.445718   47.13541  53.211800  46.397568  636.458300   76.58897
# ...           ...        ...        ...        ...         ...        ...
# 220315   2.407350   47.69965  50.520830  43.142361  634.722229   64.59095
# 220316   2.400463   47.69965  50.564240  43.142361  630.902771   65.83363
# 220317   2.396528   47.69965  50.520830  43.142361  625.925903   67.29445
# 220318   2.406366   47.69965  50.520832  43.142361  635.648100   65.09175
# 220319   2.396528   47.69965  50.520832  43.142361  639.814800   65.45634
#
#         sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_42  sensor_43  \
# 0        13.41146   16.13136   15.56713   15.05353  ...  31.770832   41.92708
# 1        13.41146   16.13136   15.56713   15.05353  ...  31.770832   41.92708
# 2        13.32465   16.03733   15.61777   15.01013  ...  31.770830   41.66666
# 3        13.31742   16.24711   15.69734   15.08247  ...  31.510420   40.88541
# 4        13.35359   16.21094   15.69734   15.08247  ...  31.510420   41.40625
# ...           ...        ...        ...        ...  ...        ...        ...
# 220315   15.11863   16.65220   15.65393   15.16204  ...  30.208330   38.28125
# 220316   15.15480   16.70284   15.65393   15.11863  ...  29.947920   38.28125
# 220317   15.08970   16.70284   15.69734   15.11863  ...  30.208330   39.06250
# 220318   15.11863   16.56539   15.74074   15.11863  ...  30.208332   40.62500
# 220319   15.11863   16.65220   15.65393   15.01013  ...  30.208332   41.40625
#
#         sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# 0       39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 1       39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 2       39.351852   65.39352   51.21528  38.194443   155.9606   67.12963
# 3       39.062500   64.81481   51.21528  38.194440   155.9606   66.84028
# 4       38.773150   65.10416   51.79398  38.773150   158.2755   66.55093
# ...           ...        ...        ...        ...        ...        ...
# 220315  68.287030   52.37268   48.32176  41.087960   212.3843  153.64580
# 220316  66.840280   50.63657   48.03241  40.798610   213.8310  156.25000
# 220317  65.393520   48.90046   48.03241  40.798610   217.3032  155.38190
# 220318  64.236110   47.74306   48.32176  40.509258   222.5116  153.93520
# 220319  62.789350   46.29630   48.90046  40.219910   227.4306  150.46300
#
#         sensor_50  sensor_51
# 0        243.0556   201.3889
# 1        243.0556   201.3889
# 2        241.3194   203.7037
# 3        240.4514   203.1250
# 4        242.1875   201.3889
# ...           ...        ...
# 220315        NaN   231.1921
# 220316        NaN   231.1921
# 220317        NaN   232.0602
# 220318        NaN   234.0856
# 220319        NaN   234.0856
#
# [220320 rows x 52 columns]

# %%
df.describe()
# Out:
#             Samplenr      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  210112.000000  219951.000000  220301.000000
# mean   110159.500000       2.372221      47.591611      50.867392
# std     63601.049991       0.412227       3.296666       3.666820
# min         0.000000       0.000000       0.000000      33.159720
# 25%     55079.750000       2.438831      46.310760      50.390620
# 50%    110159.500000       2.456539      48.133678      51.649300
# 75%    165239.250000       2.499826      49.479160      52.777770
# max    220319.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220301.000000  220301.000000  220301.000000  215522.000000
# mean       43.752481     590.673936      73.396414      13.501537
# std         2.418887     144.023912      17.298247       2.163736
# min        31.640620       2.798032       0.000000       0.014468
# 25%        42.838539     626.620400      69.976260      13.346350
# 50%        44.227428     632.638916      75.576790      13.642940
# 75%        45.312500     637.615723      80.912150      14.539930
# max        48.220490     800.000000      99.999880      22.251160
#
#            sensor_07      sensor_08  ...      sensor_42      sensor_43  \
# count  214869.000000  215213.000000  ...  220293.000000  220293.000000
# mean       15.843152      15.200721  ...      35.453455      43.879591
# std         2.201155       2.037390  ...      10.259521      11.044404
# min         0.000000       0.028935  ...      22.135416      24.479166
# 25%        15.907120      15.183740  ...      32.812500      39.583330
# 50%        16.167530      15.494790  ...      35.156250      42.968750
# 75%        16.427950      15.697340  ...      36.979164      46.614580
# max        23.596640      24.348960  ...     374.218800     408.593700
#
#            sensor_44      sensor_45      sensor_46      sensor_47  \
# count  220293.000000  220293.000000  220293.000000  220293.000000
# mean       42.656877      43.094984      48.018585      44.340903
# std        11.576355      12.837520      15.641284      10.442437
# min        25.752316      26.331018      26.331018      27.199070
# 25%        36.747684      36.747684      40.509258      39.062500
# 50%        40.509260      40.219910      44.849540      42.534720
# 75%        45.138890      44.849540      51.215280      46.585650
# max      1000.000000     320.312500     370.370400     303.530100
#
#            sensor_48      sensor_49      sensor_50      sensor_51
# count  220293.000000  220293.000000  143303.000000  204937.000000
# mean      150.889044      57.119968     183.049260     202.699667
# std        82.244957      19.143598      65.258650     109.588607
# min        26.331018      26.620370      27.488426      27.777779
# 25%        83.912030      47.743060     167.534700     179.108800
# 50%       138.020800      52.662040     193.865700     197.338000
# 75%       208.333300      60.763890     219.907400     216.724500
# max       561.632000     464.409700    1000.000000    1000.000000
#
# [8 rows x 53 columns]

# %%
fill_value = -1.0
data_with_gaps_filled = df.fillna( fill_value )

# %%
data_with_gaps_filled.isna().sum()
# Out:
# Samplenr          0
# timestamp         0
# sensor_00         0
# sensor_01         0
# sensor_02         0
# sensor_03         0
# sensor_04         0
# sensor_05         0
# sensor_06         0
# sensor_07         0
# sensor_08         0
# sensor_09         0
# sensor_10         0
# sensor_11         0
# sensor_12         0
# sensor_13         0
# sensor_14         0
# sensor_15         0
# sensor_16         0
# sensor_17         0
# sensor_18         0
# sensor_19         0
# sensor_20         0
# sensor_21         0
# sensor_22         0
# sensor_23         0
# sensor_24         0
# sensor_25         0
# sensor_26         0
# sensor_27         0
# sensor_28         0
# sensor_29         0
# sensor_30         0
# sensor_31         0
# sensor_32         0
# sensor_33         0
# sensor_34         0
# sensor_35         0
# sensor_36         0
# sensor_37         0
# sensor_38         0
# sensor_39         0
# sensor_40         0
# sensor_41         0
# sensor_42         0
# sensor_43         0
# sensor_44         0
# sensor_45         0
# sensor_46         0
# sensor_47         0
# sensor_48         0
# sensor_49         0
# sensor_50         0
# sensor_51         0
# machine_status    0
# dtype: int64

# %% [markdown]
# # Prepare data for training and testing

# %% [markdown]
# ## How to get an example input window

# %%
sensordata_cols_only = data_with_gaps_filled.iloc[:,2:54]

# %%
sensordata_cols_only
# Out:
#         sensor_00  sensor_01  sensor_02  sensor_03   sensor_04  sensor_05  \
# 0        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 1        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 2        2.444734   47.35243  53.211800  46.397570  638.888900   73.54598
# 3        2.460474   47.09201  53.168400  46.397568  628.125000   76.98898
# 4        2.445718   47.13541  53.211800  46.397568  636.458300   76.58897
# ...           ...        ...        ...        ...         ...        ...
# 220315   2.407350   47.69965  50.520830  43.142361  634.722229   64.59095
# 220316   2.400463   47.69965  50.564240  43.142361  630.902771   65.83363
# 220317   2.396528   47.69965  50.520830  43.142361  625.925903   67.29445
# 220318   2.406366   47.69965  50.520832  43.142361  635.648100   65.09175
# 220319   2.396528   47.69965  50.520832  43.142361  639.814800   65.45634
#
#         sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_42  sensor_43  \
# 0        13.41146   16.13136   15.56713   15.05353  ...  31.770832   41.92708
# 1        13.41146   16.13136   15.56713   15.05353  ...  31.770832   41.92708
# 2        13.32465   16.03733   15.61777   15.01013  ...  31.770830   41.66666
# 3        13.31742   16.24711   15.69734   15.08247  ...  31.510420   40.88541
# 4        13.35359   16.21094   15.69734   15.08247  ...  31.510420   41.40625
# ...           ...        ...        ...        ...  ...        ...        ...
# 220315   15.11863   16.65220   15.65393   15.16204  ...  30.208330   38.28125
# 220316   15.15480   16.70284   15.65393   15.11863  ...  29.947920   38.28125
# 220317   15.08970   16.70284   15.69734   15.11863  ...  30.208330   39.06250
# 220318   15.11863   16.56539   15.74074   15.11863  ...  30.208332   40.62500
# 220319   15.11863   16.65220   15.65393   15.01013  ...  30.208332   41.40625
#
#         sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# 0       39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 1       39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 2       39.351852   65.39352   51.21528  38.194443   155.9606   67.12963
# 3       39.062500   64.81481   51.21528  38.194440   155.9606   66.84028
# 4       38.773150   65.10416   51.79398  38.773150   158.2755   66.55093
# ...           ...        ...        ...        ...        ...        ...
# 220315  68.287030   52.37268   48.32176  41.087960   212.3843  153.64580
# 220316  66.840280   50.63657   48.03241  40.798610   213.8310  156.25000
# 220317  65.393520   48.90046   48.03241  40.798610   217.3032  155.38190
# 220318  64.236110   47.74306   48.32176  40.509258   222.5116  153.93520
# 220319  62.789350   46.29630   48.90046  40.219910   227.4306  150.46300
#
#         sensor_50  sensor_51
# 0        243.0556   201.3889
# 1        243.0556   201.3889
# 2        241.3194   203.7037
# 3        240.4514   203.1250
# 4        242.1875   201.3889
# ...           ...        ...
# 220315    -1.0000   231.1921
# 220316    -1.0000   231.1921
# 220317    -1.0000   232.0602
# 220318    -1.0000   234.0856
# 220319    -1.0000   234.0856
#
# [220320 rows x 52 columns]

# %% [markdown]
# Scale data column-wise to feature range [0,1]. If all inputs are in the same range, it makes it easier for a MLP to learn.

# %%
from sklearn.preprocessing import MinMaxScaler

# create a MinMaxScaler with feature range [0,1]
scaler = MinMaxScaler(feature_range=(0, 1))

scaled_sensor_data = scaler.fit_transform(sensordata_cols_only)

# %%
scaled_sensor_data
# Out:
# array([[0.97643798, 0.83308767, 0.95053407, ..., 0.1476298 , 0.24381179,
#         0.20218671],
#        [0.97643798, 0.83308767, 0.95053407, ..., 0.1476298 , 0.24381179,
#         0.20218671],
#        [0.97061664, 0.83759887, 0.95053407, ..., 0.14638636, 0.24207732,
#         0.2044992 ],
#        ...,
#        [0.95703372, 0.84361368, 0.90335138, ..., 0.33600911, 0.        ,
#         0.23282737],
#        [0.95980576, 0.84361368, 0.90335141, ..., 0.33290067, 0.        ,
#         0.23485075],
#        [0.95703372, 0.84361368, 0.90335141, ..., 0.32544014, 0.        ,
#         0.23485075]])

# %%
window_width_input_minutes = 60
window_width_output_minutes = 60*24

# %%
start_minute = 0
a_single_input_window = scaled_sensor_data[start_minute:start_minute+window_width_input_minutes]

# %%
type(a_single_input_window)
# Out:
# numpy.ndarray

# %%
# <a_single_input_window> contains the data for 60 minutes
# for each of the 52 sensors
a_single_input_window.shape
# Out:
# (60, 52)

# %%
# Map window to a vector, since we need a 1D input for the MLP
a_single_input_vector = a_single_input_window.flatten()

# %%
a_single_input_vector.shape
# Out:
# (3120,)

# %% [markdown]
# ## How to check whether the System failed in some time window after the input window

# %%
def check_for_machine_failure(start, stop):
    """
    Returns 1, if the machine failed in time window
    (start,stop)
    
    Returns 0, else.
    """
    for minute in range(start,stop):
        # get the corresponding row from the data
        machine_state_in_this_minute = df["machine_status"].iloc[minute]
        if machine_state_in_this_minute in ["BROKEN", "RECOVERING"]:
            return 1
    
    return 0

# %%
row_numbers_machine_BROKEN
# Out:
# [17155, 24510, 69318, 77790, 128040, 141131, 166440]

# %%
check_for_machine_failure(0,17000)
# Out:
# 0

# %%
check_for_machine_failure(17000,17200)
# Out:
# 1

# %%
check_for_machine_failure(20000,30000)
# Out:
# 1

# %%
check_for_machine_failure(65000,69318)
# Out:
# 0

# %%
check_for_machine_failure(65000,69319)
# Out:
# 1

# %% [markdown]
# ## Prepare example data

# %%
# Max row nr such that input window and output window
# still fit into the time series data?
max_row_nr = nr_rows_total-window_width_input_minutes-window_width_output_minutes

# collect the desired number of (input_vec,output_vec) examples
training_pairs = []
for example_nr in range(0,nr_examples_to_prepare):
    
    # show progress
    if example_nr % 100 == 0:
        print("Collected examples so far:", example_nr)
    
    # 1. guess a random minute
    found_example_where_machine_worked_in_input_window = False
    while not found_example_where_machine_worked_in_input_window:
    
        rnd_minute = np.random.randint(0,max_row_nr)
        
        # Make sure, the input window does not cover
        # already a phase where the machine is broken:
        # We want examples where the input window covers
        # a normal state and we want to predict whether
        # the machine will fail or not in the next time window
        # We do NOT want to collect examples where the machine is
        # already BROKEN in the input window
        # (could be too easy to predict whether the machine
        #  will be broken in the future as well)
        start = rnd_minute
        stop  = start+window_width_input_minutes
        if check_for_machine_failure(start,stop)==0:
            found_example_where_machine_worked_in_input_window = True
            
    
    # 2. get the input vector from the 2D sensor matrix data
    a_single_input_window = scaled_sensor_data[rnd_minute:rnd_minute+window_width_input_minutes]
    a_single_input_vector = a_single_input_window.flatten()
    
    # 3. check whether in time range
    #    (rnd_minute+window_width_input_minutes,
    #     rnd_minute+window_width_input_minutes+window_width_output_minutes)
    #    the machine failed
    start = rnd_minute+window_width_input_minutes
    stop  = rnd_minute+window_width_input_minutes+window_width_output_minutes
    output_value = check_for_machine_failure(start,stop)
    
    # 4. add a new training pair to list of training pairs
    training_pairs.append( (a_single_input_vector, output_value) )
# Out:
# Collected examples so far: 0
# Collected examples so far: 100
# Collected examples so far: 200
# Collected examples so far: 300
# Collected examples so far: 400
# Collected examples so far: 500
# Collected examples so far: 600
# Collected examples so far: 700
# Collected examples so far: 800
# Collected examples so far: 900
# Collected examples so far: 1000
# Collected examples so far: 1100
# Collected examples so far: 1200
# Collected examples so far: 1300
# Collected examples so far: 1400
# Collected examples so far: 1500
# Collected examples so far: 1600
# Collected examples so far: 1700
# Collected examples so far: 1800
# Collected examples so far: 1900

# %%
len(training_pairs)
# Out:
# 2000

# %% [markdown]
# ## Prepare a large example data matrix D from the list of training pairs

# %%
input_vec_len = training_pairs[0][0].shape[0]
output_vec_len = 1


D = np.zeros( (nr_examples_to_prepare, input_vec_len+output_vec_len))
print("Shape of D is", D.shape)

# Fill data matrix D with input vec + output vec in each row
for nr in range(0,nr_examples_to_prepare):
    (x,y) = training_pairs[nr]
    D[nr,0:input_vec_len] = x
    D[nr,input_vec_len]   = y
# Out:
# Shape of D is (2000, 3121)

# %% [markdown]
# ## From example data matrix get train and test matrices

# %%
nr_train_samples = int(nr_examples_to_prepare/2)
x_train = D[0:nr_train_samples, 0:input_vec_len]
y_train = D[0:nr_train_samples, input_vec_len]

# %%
x_train.shape
# Out:
# (1000, 3120)

# %%
y_train.shape
# Out:
# (1000,)

# %%
x_test = D[nr_train_samples:, 0:input_vec_len]
y_test = D[nr_train_samples:, input_vec_len]

# %%
x_test.shape
# Out:
# (1000, 3120)

# %%
y_test.shape
# Out:
# (1000,)

# %% [markdown]
# # Build MLP and train it

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.1.0'

# %% [markdown]
# Jetzt bauen wir das MLP mit Keras zusammen!

# %%
import tensorflow as tf
from tensorflow.keras import layers
model = tf.keras.Sequential()
model.add(layers.Dense(200, activation='relu', input_shape=(input_vec_len,)) )
model.add(layers.Dense(40, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer='sgd',               
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])

model.build()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               624200
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                8040
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 632,281
# Trainable params: 632,281
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Jetzt trainieren wir das Modell!

# %%
history = model.fit(x_train, y_train, epochs=3000)
# Out:
# Train on 1000 samples
# Epoch 1/3000
# 1000/1000 [==============================] - 1s 568us/sample - loss: 0.9545 - accuracy: 0.8890
# Epoch 2/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0548 - accuracy: 0.9430
# Epoch 3/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0538 - accuracy: 0.9430
# Epoch 4/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0538 - accuracy: 0.9430
# Epoch 5/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0537 - accuracy: 0.9430
# Epoch 6/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0542 - accuracy: 0.9430
# Epoch 7/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0537 - accuracy: 0.9430
# Epoch 8/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0529 - accuracy: 0.9430
# Epoch 9/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0532 - accuracy: 0.9430
# Epoch 10/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0524 - accuracy: 0.9430
# Epoch 11/3000
# 1000/1000 [==============================] - 0s 111us/sample - loss: 0.0524 - accuracy: 0.9430
# Epoch 12/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0520 - accuracy: 0.9430
# Epoch 13/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0525 - accuracy: 0.9430
# Epoch 14/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0522 - accuracy: 0.9430
# Epoch 15/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0522 - accuracy: 0.9430
# Epoch 16/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0525 - accuracy: 0.9430
# Epoch 17/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0523 - accuracy: 0.9430
# Epoch 18/3000
# 1000/1000 [==============================] - 0s 129us/sample - loss: 0.0516 - accuracy: 0.9430
# Epoch 19/3000
# 1000/1000 [==============================] - 0s 120us/sample - loss: 0.0517 - accuracy: 0.9430
# Epoch 20/3000
# 1000/1000 [==============================] - 0s 135us/sample - loss: 0.0517 - accuracy: 0.9430
# Epoch 21/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0513 - accuracy: 0.9430
# Epoch 22/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0520 - accuracy: 0.9430
# Epoch 23/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0511 - accuracy: 0.9430
# Epoch 24/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0517 - accuracy: 0.9430
# Epoch 25/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0507 - accuracy: 0.9430
# Epoch 26/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0514 - accuracy: 0.9430
# Epoch 27/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0508 - accuracy: 0.9430
# Epoch 28/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0507 - accuracy: 0.9430
# Epoch 29/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0511 - accuracy: 0.9430
# Epoch 30/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0508 - accuracy: 0.9430
# Epoch 31/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0511 - accuracy: 0.9430
# Epoch 32/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0503 - accuracy: 0.9430
# Epoch 33/3000
# 1000/1000 [==============================] - 0s 111us/sample - loss: 0.0503 - accuracy: 0.9430
# Epoch 34/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0518 - accuracy: 0.9430
# Epoch 35/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0504 - accuracy: 0.9430
# Epoch 36/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0502 - accuracy: 0.9430
# Epoch 37/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0514 - accuracy: 0.9430
# Epoch 38/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0502 - accuracy: 0.9430
# Epoch 39/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0500 - accuracy: 0.9430
# Epoch 40/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0495 - accuracy: 0.9430
# Epoch 41/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0503 - accuracy: 0.9430
# Epoch 42/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0504 - accuracy: 0.9430
# Epoch 43/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0498 - accuracy: 0.9430
# Epoch 44/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0499 - accuracy: 0.9430
# Epoch 45/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0497 - accuracy: 0.9430
# Epoch 46/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0492 - accuracy: 0.9430
# Epoch 47/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0495 - accuracy: 0.9430
# Epoch 48/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0496 - accuracy: 0.9430
# Epoch 49/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0492 - accuracy: 0.9430
# Epoch 50/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0487 - accuracy: 0.9430
# Epoch 51/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0496 - accuracy: 0.9430
# Epoch 52/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0497 - accuracy: 0.9430
# Epoch 53/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0491 - accuracy: 0.9430
# Epoch 54/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0494 - accuracy: 0.9430
# Epoch 55/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0488 - accuracy: 0.9430
# Epoch 56/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0487 - accuracy: 0.9430
# Epoch 57/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0487 - accuracy: 0.9430
# Epoch 58/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0483 - accuracy: 0.9430
# Epoch 59/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0491 - accuracy: 0.9430
# Epoch 60/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0486 - accuracy: 0.9430
# Epoch 61/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0488 - accuracy: 0.9430
# Epoch 62/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0483 - accuracy: 0.9430
# Epoch 63/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0494 - accuracy: 0.9430
# Epoch 64/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0479 - accuracy: 0.9430
# Epoch 65/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0482 - accuracy: 0.9430
# Epoch 66/3000
# 1000/1000 [==============================] - 0s 110us/sample - loss: 0.0476 - accuracy: 0.9430
# Epoch 67/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0483 - accuracy: 0.9430
# Epoch 68/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0483 - accuracy: 0.9430
# Epoch 69/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0477 - accuracy: 0.9430
# Epoch 70/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0477 - accuracy: 0.9430
# Epoch 71/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0478 - accuracy: 0.9430
# Epoch 72/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0474 - accuracy: 0.9430
# Epoch 73/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0486 - accuracy: 0.9430
# Epoch 74/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0478 - accuracy: 0.9430
# Epoch 75/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0472 - accuracy: 0.9430
# Epoch 76/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0480 - accuracy: 0.9430
# Epoch 77/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0475 - accuracy: 0.9430
# Epoch 78/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0465 - accuracy: 0.9430
# Epoch 79/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0468 - accuracy: 0.9430
# Epoch 80/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0479 - accuracy: 0.9430
# Epoch 81/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0472 - accuracy: 0.9430
# Epoch 82/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0465 - accuracy: 0.9430
# Epoch 83/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0471 - accuracy: 0.9430
# Epoch 84/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0468 - accuracy: 0.9430
# Epoch 85/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0466 - accuracy: 0.9430
# Epoch 86/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0469 - accuracy: 0.9430
# Epoch 87/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0463 - accuracy: 0.9430
# Epoch 88/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0475 - accuracy: 0.9430
# Epoch 89/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0474 - accuracy: 0.9430
# Epoch 90/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0463 - accuracy: 0.9430
# Epoch 91/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0465 - accuracy: 0.9430
# Epoch 92/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0462 - accuracy: 0.9430
# Epoch 93/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0455 - accuracy: 0.9430
# Epoch 94/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0465 - accuracy: 0.9430
# Epoch 95/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0450 - accuracy: 0.9430
# Epoch 96/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0456 - accuracy: 0.9430
# Epoch 97/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0456 - accuracy: 0.9440
# Epoch 98/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0458 - accuracy: 0.9430
# Epoch 99/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0454 - accuracy: 0.9430
# Epoch 100/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0452 - accuracy: 0.9440
# Epoch 101/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0449 - accuracy: 0.9440
# Epoch 102/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0457 - accuracy: 0.9440
# Epoch 103/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0449 - accuracy: 0.9440
# Epoch 104/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0455 - accuracy: 0.9440
# Epoch 105/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0462 - accuracy: 0.9440
# Epoch 106/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0446 - accuracy: 0.9440
# Epoch 107/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0456 - accuracy: 0.9440
# Epoch 108/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0438 - accuracy: 0.9440
# Epoch 109/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0462 - accuracy: 0.9440
# Epoch 110/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0447 - accuracy: 0.9440
# Epoch 111/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0449 - accuracy: 0.9440
# Epoch 112/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0448 - accuracy: 0.9450
# Epoch 113/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0440 - accuracy: 0.9440
# Epoch 114/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0441 - accuracy: 0.9450
# Epoch 115/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0455 - accuracy: 0.9450
# Epoch 116/3000
# 1000/1000 [==============================] - 0s 128us/sample - loss: 0.0449 - accuracy: 0.9440
# Epoch 117/3000
# 1000/1000 [==============================] - 0s 122us/sample - loss: 0.0435 - accuracy: 0.9450
# Epoch 118/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0447 - accuracy: 0.9450
# Epoch 119/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0444 - accuracy: 0.9450
# Epoch 120/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0438 - accuracy: 0.9450
# Epoch 121/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0435 - accuracy: 0.9450
# Epoch 122/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0433 - accuracy: 0.9450
# Epoch 123/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0432 - accuracy: 0.9450
# Epoch 124/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0436 - accuracy: 0.9450
# Epoch 125/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0434 - accuracy: 0.9450
# Epoch 126/3000
# 1000/1000 [==============================] - 0s 130us/sample - loss: 0.0437 - accuracy: 0.9450
# Epoch 127/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0443 - accuracy: 0.9450
# Epoch 128/3000
# 1000/1000 [==============================] - 0s 106us/sample - loss: 0.0446 - accuracy: 0.9450
# Epoch 129/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0432 - accuracy: 0.9450
# Epoch 130/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0442 - accuracy: 0.9450
# Epoch 131/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0425 - accuracy: 0.9450
# Epoch 132/3000
# 1000/1000 [==============================] - 0s 107us/sample - loss: 0.0445 - accuracy: 0.9460
# Epoch 133/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0450 - accuracy: 0.9450
# Epoch 134/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0430 - accuracy: 0.9450
# Epoch 135/3000
# 1000/1000 [==============================] - 0s 107us/sample - loss: 0.0414 - accuracy: 0.9450
# Epoch 136/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0429 - accuracy: 0.9450
# Epoch 137/3000
# 1000/1000 [==============================] - 0s 106us/sample - loss: 0.0464 - accuracy: 0.9460
# Epoch 138/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0424 - accuracy: 0.9450
# Epoch 139/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0416 - accuracy: 0.9450
# Epoch 140/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0413 - accuracy: 0.9460
# Epoch 141/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0437 - accuracy: 0.9460
# Epoch 142/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0428 - accuracy: 0.9450
# Epoch 143/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0442 - accuracy: 0.9460
# Epoch 144/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0416 - accuracy: 0.9460
# Epoch 145/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0430 - accuracy: 0.9470
# Epoch 146/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0414 - accuracy: 0.9450
# Epoch 147/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0425 - accuracy: 0.9460
# Epoch 148/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0429 - accuracy: 0.9460
# Epoch 149/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0427 - accuracy: 0.9460
# Epoch 150/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0423 - accuracy: 0.9450
# Epoch 151/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0424 - accuracy: 0.9450
# Epoch 152/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0403 - accuracy: 0.9470
# Epoch 153/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0420 - accuracy: 0.9450
# Epoch 154/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0448 - accuracy: 0.9460
# Epoch 155/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0414 - accuracy: 0.9470
# Epoch 156/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0406 - accuracy: 0.9450
# Epoch 157/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0399 - accuracy: 0.9480
# Epoch 158/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0411 - accuracy: 0.9460
# Epoch 159/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0438 - accuracy: 0.9470
# Epoch 160/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0421 - accuracy: 0.9460
# Epoch 161/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0397 - accuracy: 0.9460
# Epoch 162/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0408 - accuracy: 0.9470
# Epoch 163/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0444 - accuracy: 0.9440
# Epoch 164/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0408 - accuracy: 0.9470
# Epoch 165/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0412 - accuracy: 0.9470
# Epoch 166/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0432 - accuracy: 0.9460
# Epoch 167/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0397 - accuracy: 0.9470
# Epoch 168/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0402 - accuracy: 0.9470
# Epoch 169/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0397 - accuracy: 0.9470
# Epoch 170/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0395 - accuracy: 0.9470
# Epoch 171/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0420 - accuracy: 0.9480
# Epoch 172/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0387 - accuracy: 0.9470
# Epoch 173/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0389 - accuracy: 0.9480
# Epoch 174/3000
# 1000/1000 [==============================] - 0s 122us/sample - loss: 0.0403 - accuracy: 0.9470
# Epoch 175/3000
# 1000/1000 [==============================] - 0s 110us/sample - loss: 0.0392 - accuracy: 0.9470
# Epoch 176/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0399 - accuracy: 0.9470
# Epoch 177/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0392 - accuracy: 0.9470
# Epoch 178/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0391 - accuracy: 0.9480
# Epoch 179/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0396 - accuracy: 0.9470
# Epoch 180/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0400 - accuracy: 0.9470
# Epoch 181/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0386 - accuracy: 0.9470
# Epoch 182/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0398 - accuracy: 0.9480
# Epoch 183/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0398 - accuracy: 0.9470
# Epoch 184/3000
# 1000/1000 [==============================] - 0s 107us/sample - loss: 0.0384 - accuracy: 0.9470
# Epoch 185/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0395 - accuracy: 0.9480
# Epoch 186/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0389 - accuracy: 0.9480
# Epoch 187/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0386 - accuracy: 0.9490
# Epoch 188/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0399 - accuracy: 0.9470
# Epoch 189/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0390 - accuracy: 0.9480
# Epoch 190/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0406 - accuracy: 0.9480
# Epoch 191/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0616 - accuracy: 0.9230
# Epoch 192/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0460 - accuracy: 0.9470
# Epoch 193/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0458 - accuracy: 0.9470
# Epoch 194/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0451 - accuracy: 0.9470
# Epoch 195/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0444 - accuracy: 0.9470
# Epoch 196/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0427 - accuracy: 0.9470
# Epoch 197/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0415 - accuracy: 0.9470
# Epoch 198/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0416 - accuracy: 0.9470
# Epoch 199/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0394 - accuracy: 0.9470
# Epoch 200/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0389 - accuracy: 0.9480
# Epoch 201/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0406 - accuracy: 0.9490
# Epoch 202/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0381 - accuracy: 0.9480
# Epoch 203/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0382 - accuracy: 0.9480
# Epoch 204/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0387 - accuracy: 0.9480
# Epoch 205/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0372 - accuracy: 0.9490
# Epoch 206/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0387 - accuracy: 0.9490
# Epoch 207/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0397 - accuracy: 0.9480
# Epoch 208/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0386 - accuracy: 0.9500
# Epoch 209/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0399 - accuracy: 0.9480
# Epoch 210/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0381 - accuracy: 0.9500
# Epoch 211/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0381 - accuracy: 0.9480
# Epoch 212/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0372 - accuracy: 0.9480
# Epoch 213/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0370 - accuracy: 0.9490
# Epoch 214/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0382 - accuracy: 0.9510
# Epoch 215/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0382 - accuracy: 0.9490
# Epoch 216/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0352 - accuracy: 0.9490
# Epoch 217/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0384 - accuracy: 0.9520
# Epoch 218/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0383 - accuracy: 0.9460
# Epoch 219/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0370 - accuracy: 0.9510
# Epoch 220/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0372 - accuracy: 0.9480
# Epoch 221/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0373 - accuracy: 0.9480
# Epoch 222/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0381 - accuracy: 0.9500
# Epoch 223/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0361 - accuracy: 0.9520
# Epoch 224/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0385 - accuracy: 0.9510
# Epoch 225/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0370 - accuracy: 0.9490
# Epoch 226/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0390 - accuracy: 0.9480
# Epoch 227/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0374 - accuracy: 0.9490
# Epoch 228/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0356 - accuracy: 0.9520
# Epoch 229/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0383 - accuracy: 0.9490
# Epoch 230/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0351 - accuracy: 0.9530
# Epoch 231/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0407 - accuracy: 0.9460
# Epoch 232/3000
# 1000/1000 [==============================] - 0s 132us/sample - loss: 0.0357 - accuracy: 0.9510
# Epoch 233/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0368 - accuracy: 0.9510
# Epoch 234/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0372 - accuracy: 0.9510
# Epoch 235/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0390 - accuracy: 0.9510
# Epoch 236/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0343 - accuracy: 0.9550
# Epoch 237/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0363 - accuracy: 0.9530
# Epoch 238/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0353 - accuracy: 0.9510
# Epoch 239/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0378 - accuracy: 0.9490
# Epoch 240/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0360 - accuracy: 0.9490
# Epoch 241/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0343 - accuracy: 0.9580
# Epoch 242/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0342 - accuracy: 0.9540
# Epoch 243/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0356 - accuracy: 0.9530
# Epoch 244/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0352 - accuracy: 0.9550
# Epoch 245/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0387 - accuracy: 0.9490
# Epoch 246/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0361 - accuracy: 0.9550
# Epoch 247/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0365 - accuracy: 0.9500
# Epoch 248/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0363 - accuracy: 0.9520
# Epoch 249/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0379 - accuracy: 0.9500
# Epoch 250/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0374 - accuracy: 0.9470
# Epoch 251/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0348 - accuracy: 0.9530
# Epoch 252/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0355 - accuracy: 0.9510
# Epoch 253/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0348 - accuracy: 0.9540
# Epoch 254/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0364 - accuracy: 0.9500
# Epoch 255/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0346 - accuracy: 0.9510
# Epoch 256/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0352 - accuracy: 0.9570
# Epoch 257/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0360 - accuracy: 0.9500
# Epoch 258/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0346 - accuracy: 0.9540
# Epoch 259/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0329 - accuracy: 0.9540
# Epoch 260/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0350 - accuracy: 0.9560
# Epoch 261/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0331 - accuracy: 0.9530
# Epoch 262/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0330 - accuracy: 0.9540
# Epoch 263/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0336 - accuracy: 0.9580
# Epoch 264/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0332 - accuracy: 0.9570
# Epoch 265/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0324 - accuracy: 0.9550
# Epoch 266/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0346 - accuracy: 0.9530
# Epoch 267/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0331 - accuracy: 0.9560
# Epoch 268/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0368 - accuracy: 0.9520
# Epoch 269/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0358 - accuracy: 0.9490
# Epoch 270/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0349 - accuracy: 0.9530
# Epoch 271/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0368 - accuracy: 0.9510
# Epoch 272/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0318 - accuracy: 0.9600
# Epoch 273/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0336 - accuracy: 0.9620
# Epoch 274/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0362 - accuracy: 0.9550
# Epoch 275/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0329 - accuracy: 0.9610
# Epoch 276/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0332 - accuracy: 0.9640
# Epoch 277/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0344 - accuracy: 0.9550
# Epoch 278/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0340 - accuracy: 0.9540
# Epoch 279/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0324 - accuracy: 0.9590
# Epoch 280/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0337 - accuracy: 0.9590
# Epoch 281/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0322 - accuracy: 0.9580
# Epoch 282/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0325 - accuracy: 0.9590
# Epoch 283/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0320 - accuracy: 0.9560
# Epoch 284/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0324 - accuracy: 0.9630
# Epoch 285/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0383 - accuracy: 0.9520
# Epoch 286/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0341 - accuracy: 0.9560
# Epoch 287/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0318 - accuracy: 0.9610
# Epoch 288/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0337 - accuracy: 0.9570
# Epoch 289/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0322 - accuracy: 0.9620
# Epoch 290/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0351 - accuracy: 0.9560
# Epoch 291/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0371 - accuracy: 0.9510
# Epoch 292/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0303 - accuracy: 0.9600
# Epoch 293/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0407 - accuracy: 0.9520
# Epoch 294/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0337 - accuracy: 0.9580
# Epoch 295/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0336 - accuracy: 0.9580
# Epoch 296/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0319 - accuracy: 0.9650
# Epoch 297/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0343 - accuracy: 0.9540
# Epoch 298/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0323 - accuracy: 0.9610
# Epoch 299/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0322 - accuracy: 0.9640
# Epoch 300/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0304 - accuracy: 0.9660
# Epoch 301/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0302 - accuracy: 0.9630
# Epoch 302/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0311 - accuracy: 0.9620
# Epoch 303/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0328 - accuracy: 0.9580
# Epoch 304/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0346 - accuracy: 0.9520
# Epoch 305/3000
# 1000/1000 [==============================] - 0s 122us/sample - loss: 0.0332 - accuracy: 0.9620
# Epoch 306/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0339 - accuracy: 0.9580
# Epoch 307/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0314 - accuracy: 0.9630
# Epoch 308/3000
# 1000/1000 [==============================] - 0s 129us/sample - loss: 0.0301 - accuracy: 0.9620
# Epoch 309/3000
# 1000/1000 [==============================] - 0s 118us/sample - loss: 0.0389 - accuracy: 0.9480
# Epoch 310/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0330 - accuracy: 0.9530
# Epoch 311/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0304 - accuracy: 0.9650
# Epoch 312/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0320 - accuracy: 0.9580
# Epoch 313/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0333 - accuracy: 0.9580
# Epoch 314/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0300 - accuracy: 0.9600
# Epoch 315/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0348 - accuracy: 0.9570
# Epoch 316/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0315 - accuracy: 0.9650
# Epoch 317/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0322 - accuracy: 0.9610
# Epoch 318/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0317 - accuracy: 0.9630
# Epoch 319/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0312 - accuracy: 0.9630
# Epoch 320/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0359 - accuracy: 0.9490
# Epoch 321/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0295 - accuracy: 0.9650
# Epoch 322/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0295 - accuracy: 0.9630
# Epoch 323/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0370 - accuracy: 0.9540
# Epoch 324/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0312 - accuracy: 0.9650
# Epoch 325/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0334 - accuracy: 0.9590
# Epoch 326/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0298 - accuracy: 0.9630
# Epoch 327/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0307 - accuracy: 0.9630
# Epoch 328/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0311 - accuracy: 0.9630
# Epoch 329/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0324 - accuracy: 0.9640
# Epoch 330/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0317 - accuracy: 0.9570
# Epoch 331/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0373 - accuracy: 0.9530
# Epoch 332/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0285 - accuracy: 0.9700
# Epoch 333/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0304 - accuracy: 0.9680
# Epoch 334/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0320 - accuracy: 0.9640
# Epoch 335/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0286 - accuracy: 0.9660
# Epoch 336/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0303 - accuracy: 0.9650
# Epoch 337/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0492 - accuracy: 0.9350
# Epoch 338/3000
# 1000/1000 [==============================] - 0s 131us/sample - loss: 0.0420 - accuracy: 0.9470
# Epoch 339/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0417 - accuracy: 0.9470
# Epoch 340/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0413 - accuracy: 0.9470
# Epoch 341/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0409 - accuracy: 0.9470
# Epoch 342/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0411 - accuracy: 0.9470
# Epoch 343/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0400 - accuracy: 0.9470
# Epoch 344/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0399 - accuracy: 0.9470
# Epoch 345/3000
# 1000/1000 [==============================] - 0s 106us/sample - loss: 0.0397 - accuracy: 0.9470
# Epoch 346/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0392 - accuracy: 0.9470
# Epoch 347/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0395 - accuracy: 0.9470
# Epoch 348/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0394 - accuracy: 0.9470
# Epoch 349/3000
# 1000/1000 [==============================] - 0s 106us/sample - loss: 0.0403 - accuracy: 0.9470
# Epoch 350/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0398 - accuracy: 0.9470
# Epoch 351/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0383 - accuracy: 0.9470
# Epoch 352/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0388 - accuracy: 0.9470
# Epoch 353/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0383 - accuracy: 0.9470
# Epoch 354/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0384 - accuracy: 0.9470
# Epoch 355/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0384 - accuracy: 0.9470
# Epoch 356/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0378 - accuracy: 0.9470
# Epoch 357/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0386 - accuracy: 0.9470
# Epoch 358/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0384 - accuracy: 0.9470
# Epoch 359/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 0.0386 - accuracy: 0.9470
# Epoch 360/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0374 - accuracy: 0.9470
# Epoch 361/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0379 - accuracy: 0.9470
# Epoch 362/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0376 - accuracy: 0.9470
# Epoch 363/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0373 - accuracy: 0.9470
# Epoch 364/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0364 - accuracy: 0.9470
# Epoch 365/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0361 - accuracy: 0.9470
# Epoch 366/3000
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0370 - accuracy: 0.9470
# Epoch 367/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0362 - accuracy: 0.9470
# Epoch 368/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0361 - accuracy: 0.9470
# Epoch 369/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0375 - accuracy: 0.9480
# Epoch 370/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0364 - accuracy: 0.9470
# Epoch 371/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0370 - accuracy: 0.9470
# Epoch 372/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0359 - accuracy: 0.9470
# Epoch 373/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0358 - accuracy: 0.9470
# Epoch 374/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0362 - accuracy: 0.9470
# Epoch 375/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0370 - accuracy: 0.9470
# Epoch 376/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0349 - accuracy: 0.9470
# Epoch 377/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0361 - accuracy: 0.9470
# Epoch 378/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0351 - accuracy: 0.9470
# Epoch 379/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0383 - accuracy: 0.9470
# Epoch 380/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0354 - accuracy: 0.9470
# Epoch 381/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0342 - accuracy: 0.9470
# Epoch 382/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0353 - accuracy: 0.9470
# Epoch 383/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0346 - accuracy: 0.9470
# Epoch 384/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0353 - accuracy: 0.9480
# Epoch 385/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.0352 - accuracy: 0.9500
# Epoch 386/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0365 - accuracy: 0.9480
# Epoch 387/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0364 - accuracy: 0.9500
# Epoch 388/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0348 - accuracy: 0.9490
# Epoch 389/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.0347 - accuracy: 0.9490
# Epoch 390/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0345 - accuracy: 0.9470
# Epoch 391/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0356 - accuracy: 0.9480
# Epoch 392/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0339 - accuracy: 0.9490
# Epoch 393/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0341 - accuracy: 0.9500
# Epoch 394/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0347 - accuracy: 0.9510
# Epoch 395/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0350 - accuracy: 0.9500
# Epoch 396/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.0350 - accuracy: 0.9500
# Epoch 397/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.0352 - accuracy: 0.9460
# Epoch 398/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0341 - accuracy: 0.9510
# Epoch 399/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0351 - accuracy: 0.9470
# Epoch 400/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0356 - accuracy: 0.9490
# Epoch 401/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0342 - accuracy: 0.9560
# Epoch 402/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0336 - accuracy: 0.9520
# Epoch 403/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0347 - accuracy: 0.9490
# Epoch 404/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0338 - accuracy: 0.9490
# Epoch 405/3000
# 1000/1000 [==============================] - 0s 113us/sample - loss: 0.0334 - accuracy: 0.9530
# Epoch 406/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0335 - accuracy: 0.9530
# Epoch 407/3000
# 1000/1000 [==============================] - 0s 110us/sample - loss: 0.0327 - accuracy: 0.9520
# Epoch 408/3000
# 1000/1000 [==============================] - 0s 113us/sample - loss: 0.0368 - accuracy: 0.9520
# Epoch 409/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0344 - accuracy: 0.9530
# Epoch 410/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0342 - accuracy: 0.9520
# Epoch 411/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0346 - accuracy: 0.9500
# Epoch 412/3000
# 1000/1000 [==============================] - 0s 111us/sample - loss: 0.0324 - accuracy: 0.9560
# Epoch 413/3000
# 1000/1000 [==============================] - 0s 115us/sample - loss: 0.0337 - accuracy: 0.9530
# Epoch 414/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0330 - accuracy: 0.9540
# Epoch 415/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0342 - accuracy: 0.9560
# Epoch 416/3000
# 1000/1000 [==============================] - 0s 115us/sample - loss: 0.0338 - accuracy: 0.9540
# Epoch 417/3000
# 1000/1000 [==============================] - 0s 117us/sample - loss: 0.0325 - accuracy: 0.9540
# Epoch 418/3000
# 1000/1000 [==============================] - 0s 117us/sample - loss: 0.0339 - accuracy: 0.9530
# Epoch 419/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0334 - accuracy: 0.9560
# Epoch 420/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0346 - accuracy: 0.9480
# Epoch 421/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0327 - accuracy: 0.9520
# Epoch 422/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0339 - accuracy: 0.9510
# Epoch 423/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0326 - accuracy: 0.9520
# Epoch 424/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0346 - accuracy: 0.9530
# Epoch 425/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0318 - accuracy: 0.9540
# Epoch 426/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0357 - accuracy: 0.9500
# Epoch 427/3000
# 1000/1000 [==============================] - 0s 113us/sample - loss: 0.0320 - accuracy: 0.9550
# Epoch 428/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0333 - accuracy: 0.9510
# Epoch 429/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0326 - accuracy: 0.9570
# Epoch 430/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0335 - accuracy: 0.9560
# Epoch 431/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0330 - accuracy: 0.9550
# Epoch 432/3000
# 1000/1000 [==============================] - 0s 115us/sample - loss: 0.0318 - accuracy: 0.9540
# Epoch 433/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 0.0336 - accuracy: 0.9540
# Epoch 434/3000
# 1000/1000 [==============================] - 0s 114us/sample - loss: 0.0333 - accuracy: 0.9560
# Epoch 435/3000
# 1000/1000 [==============================] - 0s 115us/sample - loss: 0.0314 - accuracy: 0.9590
# Epoch 436/3000
# 1000/1000 [==============================] - 0s 117us/sample - loss: 0.0318 - accuracy: 0.9550
# Epoch 437/3000
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0316 - accuracy: 0.9560
# Epoch 438/3000
# ...
# Epoch 2862/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.5577e-04 - accuracy: 1.0000
# Epoch 2863/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 7.4633e-04 - accuracy: 0.9990
# Epoch 2864/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 4.3447e-04 - accuracy: 1.0000
# Epoch 2865/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 5.6301e-04 - accuracy: 1.0000
# Epoch 2866/3000
# 1000/1000 [==============================] - 0s 104us/sample - loss: 3.1017e-04 - accuracy: 1.0000
# Epoch 2867/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0017 - accuracy: 0.9990
# Epoch 2868/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.6750e-04 - accuracy: 1.0000
# Epoch 2869/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.6632e-04 - accuracy: 1.0000
# Epoch 2870/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 3.6070e-04 - accuracy: 1.0000
# Epoch 2871/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.5722e-04 - accuracy: 1.0000
# Epoch 2872/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.4614e-04 - accuracy: 1.0000
# Epoch 2873/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.1508e-04 - accuracy: 1.0000
# Epoch 2874/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.6190e-04 - accuracy: 1.0000
# Epoch 2875/3000
# 1000/1000 [==============================] - 0s 128us/sample - loss: 6.3437e-04 - accuracy: 1.0000
# Epoch 2876/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 3.7711e-04 - accuracy: 1.0000
# Epoch 2877/3000
# 1000/1000 [==============================] - 0s 122us/sample - loss: 4.2657e-04 - accuracy: 1.0000
# Epoch 2878/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 2.7308e-04 - accuracy: 1.0000
# Epoch 2879/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 4.8396e-04 - accuracy: 1.0000
# Epoch 2880/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.2901e-04 - accuracy: 1.0000
# Epoch 2881/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 3.9033e-04 - accuracy: 1.0000
# Epoch 2882/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 4.5662e-04 - accuracy: 1.0000
# Epoch 2883/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.4336e-04 - accuracy: 1.0000
# Epoch 2884/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 6.0756e-04 - accuracy: 1.0000
# Epoch 2885/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 3.1906e-04 - accuracy: 1.0000
# Epoch 2886/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 3.3632e-04 - accuracy: 1.0000
# Epoch 2887/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 6.7292e-04 - accuracy: 1.0000
# Epoch 2888/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 7.1444e-04 - accuracy: 1.0000
# Epoch 2889/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 5.3656e-04 - accuracy: 1.0000
# Epoch 2890/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.3002e-04 - accuracy: 1.0000
# Epoch 2891/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 4.7265e-04 - accuracy: 1.0000
# Epoch 2892/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 5.6154e-04 - accuracy: 1.0000
# Epoch 2893/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 5.5669e-04 - accuracy: 1.0000
# Epoch 2894/3000
# 1000/1000 [==============================] - 0s 120us/sample - loss: 5.6784e-04 - accuracy: 1.0000
# Epoch 2895/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.5211e-04 - accuracy: 1.0000
# Epoch 2896/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 3.9734e-04 - accuracy: 1.0000
# Epoch 2897/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.6158e-04 - accuracy: 1.0000
# Epoch 2898/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.9953e-04 - accuracy: 1.0000
# Epoch 2899/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 6.0197e-04 - accuracy: 1.0000
# Epoch 2900/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.0012 - accuracy: 0.9990
# Epoch 2901/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.1772e-04 - accuracy: 1.0000
# Epoch 2902/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 7.4383e-04 - accuracy: 1.0000
# Epoch 2903/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0013 - accuracy: 0.9990
# Epoch 2904/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.9053e-04 - accuracy: 1.0000
# Epoch 2905/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.1973e-04 - accuracy: 1.0000
# Epoch 2906/3000
# 1000/1000 [==============================] - 0s 124us/sample - loss: 3.2300e-04 - accuracy: 1.0000
# Epoch 2907/3000
# 1000/1000 [==============================] - 0s 118us/sample - loss: 3.4399e-04 - accuracy: 1.0000
# Epoch 2908/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 4.5612e-04 - accuracy: 1.0000
# Epoch 2909/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.2831e-04 - accuracy: 1.0000
# Epoch 2910/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 4.6472e-04 - accuracy: 1.0000
# Epoch 2911/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 5.5461e-04 - accuracy: 1.0000
# Epoch 2912/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 5.5547e-04 - accuracy: 1.0000
# Epoch 2913/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.5147e-04 - accuracy: 1.0000
# Epoch 2914/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.2518e-04 - accuracy: 1.0000
# Epoch 2915/3000
# 1000/1000 [==============================] - 0s 105us/sample - loss: 2.7814e-04 - accuracy: 1.0000
# Epoch 2916/3000
# 1000/1000 [==============================] - 0s 106us/sample - loss: 5.3824e-04 - accuracy: 1.0000
# Epoch 2917/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.3421e-04 - accuracy: 1.0000
# Epoch 2918/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.1200e-04 - accuracy: 1.0000
# Epoch 2919/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.8355e-04 - accuracy: 1.0000
# Epoch 2920/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.8457e-04 - accuracy: 1.0000
# Epoch 2921/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.8137e-04 - accuracy: 1.0000
# Epoch 2922/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.0557e-04 - accuracy: 1.0000
# Epoch 2923/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.5140e-04 - accuracy: 1.0000
# Epoch 2924/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.3864e-04 - accuracy: 1.0000
# Epoch 2925/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.2295e-04 - accuracy: 1.0000
# Epoch 2926/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 3.3557e-04 - accuracy: 1.0000
# Epoch 2927/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 6.6334e-04 - accuracy: 1.0000
# Epoch 2928/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.5094e-04 - accuracy: 1.0000
# Epoch 2929/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.3147e-04 - accuracy: 1.0000
# Epoch 2930/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.4878e-04 - accuracy: 1.0000
# Epoch 2931/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 3.6503e-04 - accuracy: 1.0000
# Epoch 2932/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.0902e-04 - accuracy: 1.0000
# Epoch 2933/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 4.1392e-04 - accuracy: 1.0000
# Epoch 2934/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.0564e-04 - accuracy: 1.0000
# Epoch 2935/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 5.3971e-04 - accuracy: 1.0000
# Epoch 2936/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 6.4089e-04 - accuracy: 1.0000
# Epoch 2937/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.0515e-04 - accuracy: 1.0000
# Epoch 2938/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.5547e-04 - accuracy: 1.0000
# Epoch 2939/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.1737e-04 - accuracy: 1.0000
# Epoch 2940/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 3.9315e-04 - accuracy: 1.0000
# Epoch 2941/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.3696e-04 - accuracy: 1.0000
# Epoch 2942/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 8.8740e-04 - accuracy: 1.0000
# Epoch 2943/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.6344e-04 - accuracy: 1.0000
# Epoch 2944/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 2.6067e-04 - accuracy: 1.0000
# Epoch 2945/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 3.2814e-04 - accuracy: 1.0000
# Epoch 2946/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.5678e-04 - accuracy: 1.0000
# Epoch 2947/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 3.5463e-04 - accuracy: 1.0000
# Epoch 2948/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 7.8386e-04 - accuracy: 1.0000
# Epoch 2949/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 6.2963e-04 - accuracy: 1.0000
# Epoch 2950/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.6459e-04 - accuracy: 1.0000
# Epoch 2951/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 3.3576e-04 - accuracy: 1.0000
# Epoch 2952/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.4806e-04 - accuracy: 1.0000
# Epoch 2953/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 4.6453e-04 - accuracy: 1.0000
# Epoch 2954/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 2.5755e-04 - accuracy: 1.0000
# Epoch 2955/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0011 - accuracy: 0.9990
# Epoch 2956/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 5.6087e-04 - accuracy: 1.0000
# Epoch 2957/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 4.7703e-04 - accuracy: 1.0000
# Epoch 2958/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 4.0719e-04 - accuracy: 1.0000
# Epoch 2959/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0014 - accuracy: 0.9990
# Epoch 2960/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 4.5514e-04 - accuracy: 1.0000
# Epoch 2961/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 2.3569e-04 - accuracy: 1.0000
# Epoch 2962/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 2.8118e-04 - accuracy: 1.0000
# Epoch 2963/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.9704e-04 - accuracy: 1.0000
# Epoch 2964/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.3324e-04 - accuracy: 1.0000
# Epoch 2965/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.1884e-04 - accuracy: 1.0000
# Epoch 2966/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.6742e-04 - accuracy: 1.0000
# Epoch 2967/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 2.5639e-04 - accuracy: 1.0000
# Epoch 2968/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 4.8363e-04 - accuracy: 1.0000
# Epoch 2969/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.3915e-04 - accuracy: 1.0000
# Epoch 2970/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 5.6301e-04 - accuracy: 1.0000
# Epoch 2971/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.1676e-04 - accuracy: 1.0000
# Epoch 2972/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.0329e-04 - accuracy: 1.0000
# Epoch 2973/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.5760e-04 - accuracy: 1.0000
# Epoch 2974/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 2.5040e-04 - accuracy: 1.0000
# Epoch 2975/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 4.5727e-04 - accuracy: 1.0000
# Epoch 2976/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 3.3799e-04 - accuracy: 1.0000
# Epoch 2977/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 2.8131e-04 - accuracy: 1.0000
# Epoch 2978/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 5.8890e-04 - accuracy: 1.0000
# Epoch 2979/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 6.7530e-04 - accuracy: 1.0000
# Epoch 2980/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.7399e-04 - accuracy: 1.0000
# Epoch 2981/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.3311e-04 - accuracy: 1.0000
# Epoch 2982/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 2.4952e-04 - accuracy: 1.0000
# Epoch 2983/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 3.2278e-04 - accuracy: 1.0000
# Epoch 2984/3000
# 1000/1000 [==============================] - 0s 125us/sample - loss: 3.4884e-04 - accuracy: 1.0000
# Epoch 2985/3000
# 1000/1000 [==============================] - 0s 102us/sample - loss: 2.3280e-04 - accuracy: 1.0000
# Epoch 2986/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 2.4855e-04 - accuracy: 1.0000
# Epoch 2987/3000
# 1000/1000 [==============================] - 0s 103us/sample - loss: 4.6501e-04 - accuracy: 1.0000
# Epoch 2988/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.3747e-04 - accuracy: 1.0000
# Epoch 2989/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 4.3997e-04 - accuracy: 1.0000
# Epoch 2990/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.0996e-04 - accuracy: 1.0000
# Epoch 2991/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.5218e-04 - accuracy: 1.0000
# Epoch 2992/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 3.4558e-04 - accuracy: 1.0000
# Epoch 2993/3000
# 1000/1000 [==============================] - 0s 101us/sample - loss: 4.1560e-04 - accuracy: 1.0000
# Epoch 2994/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 2.4388e-04 - accuracy: 1.0000
# Epoch 2995/3000
# 1000/1000 [==============================] - 0s 98us/sample - loss: 3.8408e-04 - accuracy: 1.0000
# Epoch 2996/3000
# 1000/1000 [==============================] - 0s 99us/sample - loss: 3.9408e-04 - accuracy: 1.0000
# Epoch 2997/3000
# 1000/1000 [==============================] - 0s 100us/sample - loss: 3.7464e-04 - accuracy: 1.0000
# Epoch 2998/3000
# 1000/1000 [==============================] - 0s 120us/sample - loss: 3.0479e-04 - accuracy: 1.0000
# Epoch 2999/3000
# 1000/1000 [==============================] - 0s 118us/sample - loss: 3.0865e-04 - accuracy: 1.0000
# Epoch 3000/3000
# 1000/1000 [==============================] - 0s 112us/sample - loss: 2.7997e-04 - accuracy: 1.0000

# %%
type(history)
# Out:
# tensorflow.python.keras.callbacks.History

# %%
type(history.history)
# Out:
# dict

# %%
history.history["loss"][:20]
# Out:
# [0.9544585348209366,
#  0.05476447718311101,
#  0.05379851764813066,
#  0.05375728489458561,
#  0.05368232941813767,
#  0.05420633135735989,
#  0.05370152110233903,
#  0.052921291023492814,
#  0.05318955133110285,
#  0.05237877081334591,
#  0.05243575819581747,
#  0.05201345396414399,
#  0.05250062883645296,
#  0.052181472323834896,
#  0.05222687954083085,
#  0.052467257481068376,
#  0.0522649687603116,
#  0.051616042220965025,
#  0.05172506097704172,
#  0.05172010293602943]

# %%
plt.plot(history.history["loss"])
plt.show()

# %% [markdown]
# # Test the final MLP

# %%
preds = model.predict(x_test)

# %%
preds.shape
# Out:
# (1000, 1)

# %%
y_test.shape
# Out:
# (1000,)

# %%
preds = preds.flatten()

# %%
preds.shape
# Out:
# (1000,)

# %%
preds[:20]
# Out:
# array([ 2.7439743e-04,  1.1626102e-02,  2.9569840e-01,  3.9336085e-04,
#        -2.6510805e-03, -7.2225928e-04,  3.2055527e-03,  1.2090543e-01,
#         9.5869303e-03,  2.4758019e-02, -5.2162260e-04,  6.2202722e-02,
#         2.8965943e-02,  5.5238605e-05,  5.7466030e-03, -1.1444464e-02,
#        -1.1369400e-02,  4.6432316e-03,  1.5217751e-01, -3.8245618e-03],
#       dtype=float32)

# %%
min(preds)
# Out:
# -0.0919908

# %%
max(preds)
# Out:
# 1.2501173

# %%
machine_failure_in_future_window = 0
correctly_predicted_machine_failures = 0
correctly_predicted = 0
nr_test_samples = preds.shape[0]

tp = 0
tn = 0
fp = 0
fn = 0

for test_nr in range(0,nr_test_samples):
    ground_truth_output = y_test[test_nr]
    if preds[test_nr] < 0.5:
        predicted_output = 0.0
    else:
        predicted_output = 1.0
    print("Test example #{0}: ground truth vs. predicted machine status: {1} vs. {2}"
          .format(test_nr, ground_truth_output, predicted_output ))
    
    if predicted_output == ground_truth_output:
        correctly_predicted +=1
        
    if ground_truth_output==1:
        machine_failure_in_future_window += 1
        if predicted_output == ground_truth_output:
            correctly_predicted_machine_failures +=1
            
    if ground_truth_output==1:
        if predicted_output == ground_truth_output:
            # True positive:
            # There was a machine failure
            # and the MLP predictor predicted it
            tp+=1
        else:
            # False negative:
            # There was a machine failure
            # BUT the MLP predictor predicted it not
            fn+=1
            
    if ground_truth_output==0:        
        if predicted_output == ground_truth_output:
            # True negative:
            # There was no machine failure
            # and the MLP predictor predicted no machine failure
            tn+=1
        else:
            # False positive:
            # There was no machine failure
            # BUT the MLP predictor predicted a machine failure
            fp+=1
            
        
correct_classification_percent = (correctly_predicted/nr_test_samples)*100.0
print("\nCorrectly predicted {0} of {1} test examples --> {2}%"
      .format(correctly_predicted, nr_test_samples, correct_classification_percent))

print("\nIf there was really a machine failure in the future window,\n"
      "the MLP could predict it in {0} of the {1} machine failure (in future window) example cases."
      .format(correctly_predicted_machine_failures, machine_failure_in_future_window))

print("True positive:", tp)
print("True negative:", tn)
print("False positive:", fp)
print("False negative:", fn)
# Out:
# Test example #0: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #1: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #2: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #3: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #4: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #5: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #6: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #7: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #8: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #9: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #10: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #11: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #12: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #13: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #14: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #15: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #16: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #17: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #18: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #19: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #20: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #21: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #22: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #23: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #24: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #25: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #26: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #27: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #28: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #29: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #30: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #31: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #32: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #33: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #34: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #35: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #36: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #37: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #38: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #39: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #40: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #41: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #42: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #43: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #44: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #45: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #46: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #47: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #48: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #49: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #50: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #51: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #52: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #53: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #54: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #55: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #56: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #57: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #58: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #59: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #60: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #61: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #62: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #63: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #64: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #65: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #66: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #67: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #68: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #69: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #70: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #71: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #72: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #73: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #74: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #75: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #76: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #77: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #78: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #79: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #80: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #81: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #82: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #83: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #84: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #85: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #86: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #87: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #88: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #89: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #90: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #91: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #92: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #93: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #94: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #95: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #96: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #97: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #98: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #99: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #100: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #101: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #102: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #103: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #104: ground truth vs. predicted machine status: 0.0 vs. 1.0
# Test example #105: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #106: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #107: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #108: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #109: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #110: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #111: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #112: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #113: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #114: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #115: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #116: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #117: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #118: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #119: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #120: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #121: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #122: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #123: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #124: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #125: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #126: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #127: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #128: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #129: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #130: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #131: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #132: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #133: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #134: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #135: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #136: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #137: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #138: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #139: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #140: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #141: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #142: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #143: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #144: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #145: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #146: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #147: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #148: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #149: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #150: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #151: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #152: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #153: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #154: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #155: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #156: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #157: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #158: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #159: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #160: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #161: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #162: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #163: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #164: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #165: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #166: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #167: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #168: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #169: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #170: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #171: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #172: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #173: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #174: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #175: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #176: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #177: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #178: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #179: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #180: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #181: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #182: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #183: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #184: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #185: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #186: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #187: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #188: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #189: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #190: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #191: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #192: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #193: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #194: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #195: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #196: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #197: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #198: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #199: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #200: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #201: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #202: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #203: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #204: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #205: ground truth vs. predicted machine status: 0.0 vs. 1.0
# Test example #206: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #207: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #208: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #209: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #210: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #211: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #212: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #213: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #214: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #215: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #216: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #217: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #218: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #219: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #220: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #221: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #222: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #223: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #224: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #225: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #226: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #227: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #228: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #229: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #230: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #231: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #232: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #233: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #234: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #235: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #236: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #237: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #238: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #239: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #240: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #241: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #242: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #243: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #244: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #245: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #246: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #247: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #248: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #249: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #250: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #251: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #252: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #253: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #254: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #255: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #256: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #257: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #258: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #259: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #260: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #261: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #262: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #263: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #264: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #265: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #266: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #267: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #268: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #269: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #270: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #271: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #272: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #273: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #274: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #275: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #276: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #277: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #278: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #279: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #280: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #281: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #282: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #283: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #284: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #285: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #286: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #287: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #288: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #289: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #290: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #291: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #292: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #293: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #294: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #295: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #296: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #297: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #298: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #299: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #300: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #301: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #302: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #303: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #304: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #305: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #306: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #307: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #308: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #309: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #310: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #311: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #312: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #313: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #314: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #315: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #316: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #317: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #318: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #319: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #320: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #321: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #322: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #323: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #324: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #325: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #326: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #327: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #328: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #329: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #330: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #331: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #332: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #333: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #334: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #335: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #336: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #337: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #338: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #339: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #340: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #341: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #342: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #343: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #344: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #345: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #346: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #347: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #348: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #349: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #350: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #351: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #352: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #353: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #354: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #355: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #356: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #357: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #358: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #359: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #360: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #361: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #362: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #363: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #364: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #365: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #366: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #367: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #368: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #369: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #370: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #371: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #372: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #373: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #374: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #375: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #376: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #377: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #378: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #379: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #380: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #381: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #382: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #383: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #384: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #385: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #386: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #387: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #388: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #389: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #390: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #391: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #392: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #393: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #394: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #395: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #396: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #397: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #398: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #399: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #400: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #401: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #402: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #403: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #404: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #405: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #406: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #407: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #408: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #409: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #410: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #411: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #412: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #413: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #414: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #415: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #416: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #417: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #418: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #419: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #420: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #421: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #422: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #423: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #424: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #425: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #426: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #427: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #428: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #429: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #430: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #431: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #432: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #433: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #434: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #435: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #436: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #437: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #438: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #439: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #440: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #441: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #442: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #443: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #444: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #445: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #446: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #447: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #448: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #449: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #450: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #451: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #452: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #453: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #454: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #455: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #456: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #457: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #458: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #459: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #460: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #461: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #462: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #463: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #464: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #465: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #466: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #467: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #468: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #469: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #470: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #471: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #472: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #473: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #474: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #475: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #476: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #477: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #478: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #479: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #480: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #481: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #482: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #483: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #484: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #485: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #486: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #487: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #488: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #489: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #490: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #491: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #492: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #493: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #494: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #495: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #496: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #497: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #498: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #499: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #500: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #501: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #502: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #503: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #504: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #505: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #506: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #507: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #508: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #509: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #510: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #511: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #512: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #513: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #514: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #515: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #516: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #517: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #518: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #519: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #520: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #521: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #522: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #523: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #524: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #525: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #526: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #527: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #528: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #529: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #530: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #531: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #532: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #533: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #534: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #535: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #536: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #537: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #538: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #539: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #540: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #541: ground truth vs. predicted machine status: 0.0 vs. 1.0
# Test example #542: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #543: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #544: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #545: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #546: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #547: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #548: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #549: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #550: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #551: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #552: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #553: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #554: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #555: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #556: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #557: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #558: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #559: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #560: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #561: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #562: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #563: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #564: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #565: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #566: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #567: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #568: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #569: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #570: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #571: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #572: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #573: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #574: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #575: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #576: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #577: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #578: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #579: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #580: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #581: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #582: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #583: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #584: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #585: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #586: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #587: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #588: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #589: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #590: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #591: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #592: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #593: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #594: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #595: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #596: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #597: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #598: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #599: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #600: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #601: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #602: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #603: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #604: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #605: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #606: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #607: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #608: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #609: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #610: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #611: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #612: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #613: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #614: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #615: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #616: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #617: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #618: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #619: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #620: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #621: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #622: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #623: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #624: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #625: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #626: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #627: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #628: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #629: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #630: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #631: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #632: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #633: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #634: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #635: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #636: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #637: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #638: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #639: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #640: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #641: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #642: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #643: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #644: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #645: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #646: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #647: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #648: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #649: ground truth vs. predicted machine status: 0.0 vs. 0.0
# ...
# Test example #788: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #789: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #790: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #791: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #792: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #793: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #794: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #795: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #796: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #797: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #798: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #799: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #800: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #801: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #802: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #803: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #804: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #805: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #806: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #807: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #808: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #809: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #810: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #811: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #812: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #813: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #814: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #815: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #816: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #817: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #818: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #819: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #820: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #821: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #822: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #823: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #824: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #825: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #826: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #827: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #828: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #829: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #830: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #831: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #832: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #833: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #834: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #835: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #836: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #837: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #838: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #839: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #840: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #841: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #842: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #843: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #844: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #845: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #846: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #847: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #848: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #849: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #850: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #851: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #852: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #853: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #854: ground truth vs. predicted machine status: 1.0 vs. 1.0
# Test example #855: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #856: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #857: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #858: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #859: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #860: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #861: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #862: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #863: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #864: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #865: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #866: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #867: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #868: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #869: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #870: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #871: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #872: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #873: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #874: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #875: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #876: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #877: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #878: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #879: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #880: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #881: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #882: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #883: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #884: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #885: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #886: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #887: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #888: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #889: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #890: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #891: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #892: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #893: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #894: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #895: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #896: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #897: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #898: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #899: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #900: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #901: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #902: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #903: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #904: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #905: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #906: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #907: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #908: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #909: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #910: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #911: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #912: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #913: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #914: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #915: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #916: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #917: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #918: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #919: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #920: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #921: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #922: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #923: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #924: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #925: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #926: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #927: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #928: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #929: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #930: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #931: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #932: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #933: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #934: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #935: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #936: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #937: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #938: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #939: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #940: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #941: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #942: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #943: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #944: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #945: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #946: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #947: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #948: ground truth vs. predicted machine status: 1.0 vs. 0.0
# Test example #949: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #950: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #951: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #952: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #953: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #954: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #955: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #956: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #957: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #958: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #959: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #960: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #961: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #962: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #963: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #964: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #965: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #966: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #967: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #968: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #969: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #970: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #971: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #972: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #973: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #974: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #975: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #976: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #977: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #978: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #979: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #980: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #981: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #982: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #983: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #984: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #985: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #986: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #987: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #988: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #989: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #990: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #991: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #992: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #993: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #994: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #995: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #996: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #997: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #998: ground truth vs. predicted machine status: 0.0 vs. 0.0
# Test example #999: ground truth vs. predicted machine status: 0.0 vs. 0.0
#
# Correctly predicted 980 of 1000 test examples --> 98.0%
#
# If there was really a pump failure in the future window,
# the MLP could predict it in 33 of the 50 pump failure (in future window) example cases.
# True positive: 33
# True negative: 947
# False positive: 3
# False negative: 17

# %%
precision = tp/(tp+fp)
recall = tp/(tp+fn)
print("Precision: {0:.2f}".format(precision))
print("Recall   : {0:.2f}".format(recall))
# Out:
# Precision: 0.92
# Recall   : 0.66

# %% [markdown]
# # Conclusion

# %%
print("The machine status can be predicted with an accuracy of {0}%".format(correct_classification_percent))
# Out:
# The machine status can be predicted with an accuracy of 98.0%
